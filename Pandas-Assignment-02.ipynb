# %%
# Q1. List any five functions of the pandas library with execution.
# Answer :-
# 1.read_csv(): This function is used to read a CSV file and create a DataFrame. It is a flexible function that can handle various file formats and has several parameters for customization.
import pandas as pd

# Read CSV file
df = pd.read_csv('data.csv')

# Print the DataFrame
print(df.head())

# 2.head(): This function is used to view the first few rows of a DataFrame. By default, it displays the first five rows, but you can specify the number of rows to display.
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bob', 'Claire'],
        'Age': [25, 30, 27],
        'Gender': ['Female', 'Male', 'Female']}
df = pd.DataFrame(data)

# Display the first three rows
print(df.head(3))

# 3.info(): This function provides a summary of the DataFrame, including the column names, data types, and the number of non-null values. It helps in understanding the structure and characteristics of the data.
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bob', 'Claire'],
        'Age': [25, 30, 27],
        'Gender': ['Female', 'Male', 'Female']}
df = pd.DataFrame(data)

# Display the summary information
df.info()

# 4.groupby(): This function is used for grouping data based on one or more columns. It enables aggregation, transformation, and applying functions to the grouped data.
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bob', 'Claire', 'Alice', 'Bob'],
        'Age': [25, 30, 27, 35, 40],
        'Gender': ['Female', 'Male', 'Female', 'Female', 'Male']}
df = pd.DataFrame(data)

# Group by 'Gender' column and calculate the average age
grouped = df.groupby('Gender')['Age'].mean()

# Display the grouped data
print(grouped)

# 5.fillna(): This function is used to fill missing values in the DataFrame with a specified value or strategy. It helps in handling missing data before performing analysis.
import pandas as pd

# Create a DataFrame with missing values
data = {'Name': ['Alice', 'Bob', None, 'Claire'],
        'Age': [25, 30, None, 27],
        'Gender': ['Female', 'Male', 'Female', None]}
df = pd.DataFrame(data)

# Fill missing values with 'Unknown'
df_filled = df.fillna('Unknown')

# Display the DataFrame with filled values
print(df_filled)

# These are just a few examples of the many functions available in the pandas library. The pandas library provides a wide range of powerful functions for data manipulation, analysis, and exploration.

# %%
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the 
# DataFrame with a new index that starts from 1 and increments by 2 for each row.
# Answer :-
# To re-index a Pandas DataFrame with a new index that starts from 1 and increments by 2 for each row, you can use the reset_index() function along with some additional steps. Here's an example Python function that achieves this:
import pandas as pd

def reindex_dataframe(df):
    # Reset the index
    df_reset = df.reset_index()

    # Create a new index starting from 1 and incrementing by 2
    new_index = pd.RangeIndex(start=1, stop=2*len(df_reset), step=2)

    # Assign the new index to the DataFrame
    df_reset['index'] = new_index

    # Set the new index as the DataFrame's index
    df_reset.set_index('index', inplace=True)

    return df_reset

new_df = reindex_dataframe(df)

# %%
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that 
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The 
# function should print the sum to the console.

# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should 
# calculate and print the sum of the first three values, which is 60.
# Answer :-
import pandas as pd

def calculate_sum(df):
    # Get the 'Values' column
    values_column = df['Values']

    # Calculate the sum of the first three values
    sum_values = values_column.head(3).sum()

    # Print the sum
    print("Sum of the first three values:", sum_values)

df = pd.DataFrame({'Values': [10, 20, 30, 40, 50]})
calculate_sum(df)

# %%
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 
# 'Word_Count' that contains the number of words in each row of the 'Text' column.
# Answer :-
import pandas as pd

def add_word_count_column(df):
    # Create a new column 'Word_Count' by applying the lambda function
    df['Word_Count'] = df['Text'].apply(lambda x: len(str(x).split()))

    return df

df = pd.DataFrame({'Text': ['Hello, how are you?', 'I am doing well.', 'Nice to meet you.']})
df = add_word_count_column(df)

# %%
# Q5. How are DataFrame.size() and DataFrame.shape() different?
# Answer :-
# The DataFrame.size() and DataFrame.shape() methods in Pandas have different functionalities and provide different information about the DataFrame:

# 1.DataFrame.size(): This method returns the total number of elements in the DataFrame. It calculates the size by multiplying the number of rows by the number of columns.
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.size)

# 2.DataFrame.shape(): This method returns a tuple representing the dimensions of the DataFrame. It provides the number of rows and columns in the DataFrame.
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.shape)

# To summarize, DataFrame.size() provides the total number of elements in the DataFrame, while DataFrame.shape() returns a tuple representing the dimensions of the DataFrame (number of rows, number of columns).

# %%
# Q6. Which function of pandas do we use to read an excel file?
# Answer :-
# In Pandas, the function used to read an Excel file is read_excel(). This function allows you to read the data from an Excel file and create a DataFrame.
# Here's an example of how to use the read_excel() function:
import pandas as pd

# Read the Excel file and create a DataFrame
df = pd.read_excel('data.xlsx')

# Print the DataFrame
print(df)

# %%
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email 
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column 
# 'Username' in df that contains only the username part of each email address.
# Answer :-
import pandas as pd

def extract_username(df):
    # Extract the username from the email addresses
    df['Username'] = df['Email'].str.split('@').str[0]

    return df

df = pd.DataFrame({'Email': ['john.doe@example.com', 'jane.smith@example.com']})
df = extract_username(df)

# %%
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects 
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The 
# function should return a new DataFrame that contains only the selected rows.
#  For example, if df contains the following values:
#  A   B   C
#  0  3   5   1
#  1  8   2   7
#  2  6   9   4
#  3  2   3   5
#  4  9   1   2
# Answer :-
import pandas as pd

def select_rows(df):
    # Select rows based on the condition
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]

    return selected_rows

df = pd.DataFrame({'A': [3, 8, 6, 2, 9],
                   'B': [5, 2, 9, 3, 1],
                   'C': [1, 7, 4, 5, 2]})
selected_df = select_rows(df)
